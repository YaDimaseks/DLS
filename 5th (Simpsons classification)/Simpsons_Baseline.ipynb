# %%
# ВНИМАНИЕ; версия Pillow установвленна по умолчанию - '7.0.0'
# Эта версия ломает torchvision
import PIL
PIL.__version__
# Out:
# '5.3.0'

# %% [markdown]
# # Автор: Dmitry_Yaremus_348296053
# # score на Kaggle: 0.99149

# %%
# !pip uninstall -y Pillow
# !pip install -Iv Pillow==5.3.0
# Out:
# Found existing installation: Pillow 7.1.2
# Uninstalling Pillow-7.1.2:
#   Successfully uninstalled Pillow-7.1.2
# Using pip 21.1.3 from /usr/local/lib/python3.7/dist-packages/pip (python 3.7)
# Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/lib/python3.7/dist-packages
# sysconfig: /usr/lib/python3.7/site-packages
# Value for scheme.purelib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/lib/python3.7/dist-packages
# sysconfig: /usr/lib/python3.7/site-packages
# Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/include/python3.7/UNKNOWN
# sysconfig: /usr/include/python3.7m/UNKNOWN
# Value for scheme.scripts does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/bin
# sysconfig: /usr/bin
# Value for scheme.data does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local
# sysconfig: /usr
# Additional context:
# user = False
# home = None
# root = None
# prefix = None
# Non-user install because site-packages writeable
# Created temporary directory: /tmp/pip-ephem-wheel-cache-gldcab41
# Created temporary directory: /tmp/pip-req-tracker-au2t4vd7
# Initialized build tracking at /tmp/pip-req-tracker-au2t4vd7
# Created build tracker: /tmp/pip-req-tracker-au2t4vd7
# Entered build tracker: /tmp/pip-req-tracker-au2t4vd7
# Created temporary directory: /tmp/pip-install-vnuj8mlw
# 1 location(s) to search for versions of pillow:
# * https://pypi.org/simple/pillow/
# Fetching project page and analyzing links: https://pypi.org/simple/pillow/
# Getting page https://pypi.org/simple/pillow/
# Found index url https://pypi.org/simple
# Looking up "https://pypi.org/simple/pillow/" in the cache
# Request header has "max_age" as 0, cache bypassed
# Starting new HTTPS connection (1): pypi.org:443
# https://pypi.org:443 "GET /simple/pillow/ HTTP/1.1" 200 203092
# Updating cache with response from "https://pypi.org/simple/pillow/"
# Caching due to etag
#   Found link https://files.pythonhosted.org/packages/72/e6/692512c5d9dc97f83a91f8a75806e0b9e910ebd8d6b0b3d6ca9a249c1e26/Pillow-1.0.tar.gz#sha256=be8643522995b49682208c065bf41d46944befe0413a90c279220a324e761f26 (from https://pypi.org/simple/pillow/), version: 1.0
#   Found link https://files.pythonhosted.org/packages/ea/dd/20ef35448408caa380cc4e570aaf6c4c4b1655a508c128ec4342e5f22d0c/Pillow-1.1.tar.gz#sha256=e17a3264df5abdfb944307cc67d4ad94b58bc49fc6df80844867d3c8c9128f16 (from https://pypi.org/simple/pillow/), version: 1.1
#   Found link https://files.pythonhosted.org/packages/ee/b9/e33d12389365e6682cc76bc3ddfd319df40138e916584185ab40f75f1acf/Pillow-1.2.tar.gz#sha256=96f8b8771524405fb2081ba12382d98bf39b7ec12473d2aea3251cbda646f885 (from https://pypi.org/simple/pillow/), version: 1.2
#   Found link https://files.pythonhosted.org/packages/d3/6e/5790f95cfadad9de79f9b36c9f610d76dc0288dddc8ce55f72dbdf533b62/Pillow-1.3.zip#sha256=d07a6e160ace99220c18894758d479930077ce95a690240c3b9add642df1f080 (from https://pypi.org/simple/pillow/), version: 1.3
#   Found link https://files.pythonhosted.org/packages/97/b1/bc176add46c7a3c576922aab552a371354793eceb867b63d0b97060e5644/Pillow-1.4.zip#sha256=a1fda49029a7cdf551b7f73190a9a095678e157ea389e117794c805a12e8cb2d (from https://pypi.org/simple/pillow/), version: 1.4
#   Found link https://files.pythonhosted.org/packages/42/38/c205550a701e3ac790992bf3d124b3514a0d1496d898237fec4057e63985/Pillow-1.5.zip#sha256=dcf33a1b239f7e4962472a57efea84a2320d7b259f5d73b4ac79bf906634775e (from https://pypi.org/simple/pillow/), version: 1.5
#   Found link https://files.pythonhosted.org/packages/35/80/58ec9cfbaa3a71707f5fe4930c6591f08ba4135bf18375419fa1eb8082f2/Pillow-1.6.zip#sha256=aafb63bf7252dd93b5930bb511517624c38be8772fcedb5bf7a61a6cac5e9a16 (from https://pypi.org/simple/pillow/), version: 1.6
#   Found link https://files.pythonhosted.org/packages/d2/af/3880d7265947e429923f38e5f298113cda2eebc3980cb06fcf6d68d4a6bc/Pillow-1.7.0.zip#sha256=9e741cacc768b6e215850e9c6acfab7b96dc4c727eb0f0a0fd4df4a47364372d (from https://pypi.org/simple/pillow/), version: 1.7.0
#   Found link https://files.pythonhosted.org/packages/70/6a/b30dc124066520f9afeaf42b07e5f6c04521aa0d30389edb4bb8058ba91d/Pillow-1.7.1.zip#sha256=3af01f698883a09ed3aae1724b39c970023ba8c78b2fc260946f90e8c531d896 (from https://pypi.org/simple/pillow/), version: 1.7.1
#   Found link https://files.pythonhosted.org/packages/10/53/ec3ad7422503a25d465f417ff204482079f094f771ebb2cb45b00ad1e3e6/Pillow-1.7.2.zip#sha256=359ce254555feeafdd98fcaa096893627a7e38b79642dc31f2a35332087a3bfc (from https://pypi.org/simple/pillow/), version: 1.7.2
#   Found link https://files.pythonhosted.org/packages/18/a5/2587cd64cc0a779ee7d34d165f0d8d1b80b094f334aea87a0309eafc67af/Pillow-1.7.3.zip#sha256=ba299e2c9506652fb18e9f8a0364f1a32dd2da2f0ded37ab778b719be3438cb5 (from https://pypi.org/simple/pillow/), version: 1.7.3
#   Found link https://files.pythonhosted.org/packages/14/9c/ba18bf24876bcb5d0cc674f08ff48a1a4ad8f5af91a5de0caad5fc0d2e9e/Pillow-1.7.4.zip#sha256=9aa3b69dd6b9493b100fc8aadaa02e36e15602d841d79f809d727e1f183af8e8 (from https://pypi.org/simple/pillow/), version: 1.7.4
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/a3/b8/415521e3034080e820bc695f85144b5ecfea89524cd1a8b219f411732cbe/Pillow-1.7.5-py2.4-win32.egg#sha256=1a807ea9456dd0ab4e91f569edbb6fbe33810434ae62a628a1d8046c3b6f1f72 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/e6/02/d8b34de1cf82f7b00b9f36f88aaa886d0d443f940c12bfa6c848dc369ed7/Pillow-1.7.5-py2.5-win32.egg#sha256=4ed2ca5f9a556312248ecac0ac77c7df9c8deb92b0a668307978fd4690b4ddfc (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/93/bd/9197645c16c846edd1dc4b8b0d70bce013fbc42f03b3a1d15111e7397fcb/Pillow-1.7.5-py2.6-win32.egg#sha256=66338b922ac169144099d47f0f41506774388162d01653e7bbf103dda23a1cc2 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/67/c8/ec83d6d78b4baa9da3ed438e313a63b1f7fb5f4c9efb0e7afa9fd31e73e1/Pillow-1.7.5-py2.7-win32.egg#sha256=675cbc916505b38abdec199f2c5bc1269027c139aa60afa57968be8de18c38b1 (from https://pypi.org/simple/pillow/)
#   Found link https://files.pythonhosted.org/packages/37/80/f793f16ec5fe22ca0678e222024bdb945964d85aeb4c54f2e626406f8e4b/Pillow-1.7.5.zip#sha256=3f7e97db13265e8c7c8e3bb60d7ad92a404034039e5448587dc6ec0e2b7d592c (from https://pypi.org/simple/pillow/), version: 1.7.5
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/3f/3c/0f6ce97ecbf73d5d16accdb8a7faa92427f678c56ddd57df8deb6df8e9b0/Pillow-1.7.6-py2.4-win32.egg#sha256=8782a941856652c28f8242d6762ce0e1b31f3eb6e40b434ba5b6380f0cec0211 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/ec/e2/103e2138aa6717d3d28b29907d3cd70d9742a747e5b7b2f1ff1a509b31b2/Pillow-1.7.6-py2.5-win32.egg#sha256=b9c1f3d90b9ccd650b1cd22e20a568e14c951a70d53a6e67d666f59f0ec75296 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/05/d6/9f92986955f720d9b3dfaf98312472db240649f38f06c302cffa870f143b/Pillow-1.7.6-py2.6-win32.egg#sha256=e224b483521eaca1b60a62c2373c823fc37995ffe511a6981fdcdcedf13bf15f (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/97/35/504440eb2fb5b376fef27f6821bc9b9dcbd9c84d04e7e19f6efa521a5b9f/Pillow-1.7.6-py2.7-win32.egg#sha256=0e4da1f37a7aabe22ed8aa6c1024b7978bfb1092b404c914b98908e3cbf1ef60 (from https://pypi.org/simple/pillow/)
#   Found link https://files.pythonhosted.org/packages/12/bc/32ecfd172731f2193dd8ed01fc4c707be93016520a4c6469078352d2c530/Pillow-1.7.6.tar.gz#sha256=b71c975984299a435d485fa23f61763b1ae0b576098d954fef2142bda035a49c (from https://pypi.org/simple/pillow/), version: 1.7.6
#   Found link https://files.pythonhosted.org/packages/f3/c6/d53213b9e85abf61e09089a22419fbbb1a074b0bf08d946735125259a044/Pillow-1.7.6.zip#sha256=d3cfed6b21bdffaab0e3722a015e1d6d7c42823d2768518f1134f15b7810f8a9 (from https://pypi.org/simple/pillow/), version: 1.7.6
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/8f/07/f50ce64128451c4f15274568f66ba69c0c6739f3a916a5f081ce7ce25fc3/Pillow-1.7.7-py2.4-win32.egg#sha256=d41f5367a21d7fe7cf3524cd5c09a8e3cb28e91c3f10f12889e8de57c7ba3295 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/62/09/e1d77645eaeec3099044fe8f2b6626fed44bcace6b3e5cf3b0abde5dade0/Pillow-1.7.7-py2.5-win32.egg#sha256=8c87a610e6613feb022f9d6e1b1a634dce30b10aee25a3ce078112a3d9652a9f (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/ff/d5/e7fe7aa85504a995c5b3d6af140d3bd6ab043dac8ae9b9141659357ab9d2/Pillow-1.7.7-py2.6-win32.egg#sha256=6cc7186ba3c994dd5257c50e61908b1b1bb7599bec4273e2bb2fb88960392da5 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/49/c6/3f772a6f11edeb340a0466e3d27c19eddba58031442eed270513f19aaa71/Pillow-1.7.7-py2.7-win32.egg#sha256=da25592f0f1c6557a697e9cdf4c83fe218cd94a3843e50164ddb8c1f93489bc8 (from https://pypi.org/simple/pillow/)
#   Found link https://files.pythonhosted.org/packages/77/93/d6eabe91dda55ac924c95763568d596e3e6082950a04c24fccf32c12324c/Pillow-1.7.7.zip#sha256=4e9a17d62bc221ed932a3bccdf710331f014e0432b61e91e7222b7c93e91de48 (from https://pypi.org/simple/pillow/), version: 1.7.7
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/65/8e/a429b8530f6e3c831102036c3406afce8eac31c79ed83889c2dd7941537c/Pillow-1.7.8-py2.4-win32.egg#sha256=b760f442b180753684522f011dc0e24c1de0c68845d4bd64c59319fe5ffa630a (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/46/71/1937fa84473e5786f397156ae19160c7e4d32eee5d5d4d3dd840f140dc85/Pillow-1.7.8-py2.5-win32.egg#sha256=ac21ec0287c0e8af7a85fa326052b6c1ca5ec4e73eecfdd0d0258520b2d397c4 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/d6/31/6e49de7ab34b613eb42b28d3c4cba9a14d9ab622d7f9f5f536e843c04667/Pillow-1.7.8-py2.6-win-amd64.egg#sha256=c77931adb1bbd02d207783cd74e813050267a103d37e165df9426721af5640a4 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/7f/43/cb0f14cc4baad7d5ac2f32337c3d49e19a27d2b57ace66b1d1845be15043/Pillow-1.7.8-py2.6-win32.egg#sha256=900b6e6115b484e373a3208d8c9b618be4a29de159335211e29038078d945bc1 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/23/a9/e6b5418a64b637b43d54ce62d4aacbe698d0ac28a3643dc076dcc2930ff8/Pillow-1.7.8-py2.7-win-amd64.egg#sha256=4bc0484b56f9d6ac84f75c5aa932f7bd3ca64c9c38b651d1d79867c6305d41b6 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/6d/aa/01916d2acea70921253858c1763e7dbb9fe6226f1b54ac036405d31dc3c8/Pillow-1.7.8-py2.7-win32.egg#sha256=a9d6005f695fe6cdde284d4d3e2b7641afefb499f58f57b9cf45c37bee9ce3a0 (from https://pypi.org/simple/pillow/)
#   Found link https://files.pythonhosted.org/packages/89/ac/e90ae7f39d78ec10c0861915a7792c6486a90c8909942aef5fcb437dbf84/Pillow-1.7.8.zip#sha256=907f5342b1df1d277dcc10df2aeabc61099e5a07e0676b9fcd1bb7379890c0ee (from https://pypi.org/simple/pillow/), version: 1.7.8
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/0f/6c/b64dfbc52116a2957ae8579a06b04851e209367ca3032346bc16aef72c23/Pillow-2.0.0-py2.6-win-amd64.egg#sha256=b448e08d660495a1306f4f15e7ef6a765d11a27374a73dda7c23c7d579963b75 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/17/8b/e925529b0757ffb6dcebca1475dbf90f2151df7c5a1222cef59cad881bcc/Pillow-2.0.0-py2.6-win32.egg#sha256=b3c242db327d4dd19866efedb16e19ed451be750f85f2abb1060e2e827c912e4 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/62/ed/6cf665a3fe25f81fbba029d428afbbe08ca86c02d9796ed2b2da3a69e69f/Pillow-2.0.0-py2.7-win-amd64.egg#sha256=9a90b9cf9789ecf1dd4fabf944059abccea3a230b394ab8584c0617491021e8f (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/4d/d0/1c3d3e673d5f471ef7084b8a3cd319566d356c4531c1d5ce742980e365b4/Pillow-2.0.0-py2.7-win32.egg#sha256=09333265cdf67eeab26ac9dfbc87088fb734129d7181da6c713f7673e53959d5 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/1a/e9/4e1257ff8753ef34ed7675fff8eaa0c1b428753da12bb0f10d50035ba478/Pillow-2.0.0-py3.2-win-amd64.egg#sha256=23f5d2641788590571d224b3cd90e6441a2b1726cceca48f60f7e0c33b0e4937 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/f8/96/a16ea6a302eb5b52304cb594e350ab2ef743a8480425616a01d2a354d6ed/Pillow-2.0.0-py3.2-win32.egg#sha256=89244f22c6dd4b06723844cc05f6f0a25058e3bacc43e82216a8c6b36cb7ef5d (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/ac/36/f902b08d1e694b225cc841ef9980af73f439ee9efc558a5717db40ef2628/Pillow-2.0.0-py3.3-win-amd64.egg#sha256=395a41c3c3436f4a142be00de59bef0db61344048e7b08f0ac0f0b23d4099fa0 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/80/cc/07dc58c00efbb7d815ff6f1c4327327663a420a823437497c2944bb3a1ce/Pillow-2.0.0-py3.3-win32.egg#sha256=9bf52822ea1d7c5c35fdc7a9cad5b273b8abf8520d758c6e2252b6ef2533e601 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/e8/11/64962e2944f6bc9569c7c1326fd8768da327a6e400ef8759b85004cf4af8/Pillow-2.0.0.win-amd64-py2.6.exe#sha256=a0835651912a8a3e0ea921964ee19fe870aa1683f0006d1742c3f76833f9b805 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/52/f6/1391c8420a4c1b9504f14a80edcbe0d53df276fd3b6b529118f5d71ade40/Pillow-2.0.0.win-amd64-py2.7.exe#sha256=0e81e6123e8c6561d97eba0a9be7e8922c3d17cc2580a4f80db5cc327fe2ccac (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/bc/df/199eaa5c45a1111f02a8ab312b90addb7c5619ec9b7f52aa382001db111f/Pillow-2.0.0.win-amd64-py3.2.exe#sha256=a39acc2118318a4281cb85cdad630145e4eeeebf5312a9f6913ed1fb0f303706 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/5b/3c/512d0c179038c827ccceb8a7efebe5eff4ca0b8480ca20ffd658f7c3a0ca/Pillow-2.0.0.win-amd64-py3.3.exe#sha256=26ae3e5b9987dc51206f2d50ecfa81dd0f6d9afe879683bc1fe87a05bc8f6488 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/49/06/8ef94bb91810eb293be538b0156a42e95b2126e2dd47b0566fa9277d2db1/Pillow-2.0.0.win32-py2.6.exe#sha256=cdb9b5e8835e4b87757dd5910323073b4ff8cc252ad37988f15072007f6cef53 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/aa/1b/a4ab6edef1a2621267e20253dead718182fdd07668781be49a5c48a45a04/Pillow-2.0.0.win32-py2.7.exe#sha256=48468858386650ad0cb8c63e98295274b6fbdee71a99ac4b763dd72020ad4c3d (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/1f/1d/431f8aeab1020588bb4aa6bac4651fab404b1830678bd9974ae36cd0a6db/Pillow-2.0.0.win32-py3.2.exe#sha256=186c050d84ef10864a03cfbdbe0e56cdd08f773fd17ddad8e541777e834344ef (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/c5/51/54cf3034171db805c98891b2285f5c44505e128ae192ab161eb77a8e17cb/Pillow-2.0.0.win32-py3.3.exe#sha256=5f51d0c60fff24d5b714834c5f5b86955115b7613f419e65b80a7ca2b84321c4 (from https://pypi.org/simple/pillow/)
#   Found link https://files.pythonhosted.org/packages/2f/2b/8d8d78b87be8f62ae9244e79d57e32b0fc78ff23ac5ecd75642b9528d948/Pillow-2.0.0.zip#sha256=3e70c8f13675284166e4a8d8899107bf67febe676b893eb8d88785c24cca4c15 (from https://pypi.org/simple/pillow/), version: 2.0.0
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/5a/10/6476717ac4d4c92395ef10448ad1a40be8c0f31757efaa6d7ec6bc77180c/Pillow-2.1.0-py2.6-win-amd64.egg#sha256=ff0c8e634b3b5d5d87ece1fb35d3a306d7d6895c671a90ec3121e6b1a498e9a4 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/00/15/e776f42afb6d79f27710aded08fd50998174f772621f1cda5d44701be1ed/Pillow-2.1.0-py2.6-win32.egg#sha256=a18b71da3e2c3cb47b26b7c2b567be5ab354634113b510e8bac77bfa46154eeb (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/5b/2c/67624237ba24f43432dc54aaa25ea6b3058a0c0e231df3d5dba213f46f31/Pillow-2.1.0-py2.7-win-amd64.egg#sha256=c4e92c0221f5e0192fc0c6caaa771c9267d292b05d6b06729d5fcf28d857b90a (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/71/19/e9cc5dde160959762fa3e4709aa8063fd0e2e0f807c8e6e81e919fc8eee3/Pillow-2.1.0-py2.7-win32.egg#sha256=2b4276085b38c0005991475811e796cafc4c0de08f460c5b4554fd806826e64f (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/19/1e/fb7fb776f632b122dbca203efe22aaa545239a6d1d64e855e9dc08aa8abb/Pillow-2.1.0-py3.2-win-amd64.egg#sha256=9d5c60a092ba4c40ebbc4e612680d1a99ed302ab94c4db2a8b3bd8038447a690 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/40/11/5280084603c1be9dae570d4e65e8f239879e1414511bf233a29272cff3d1/Pillow-2.1.0-py3.2-win32.egg#sha256=5d7bf33e1928ed71caed650d190b69da7a362b8f738d74f39a69616553c66040 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/9f/f0/c64d484e83c433414e920a9f36fd4fd15b352c0df4b4c4263a92309ba7ed/Pillow-2.1.0-py3.3-win-amd64.egg#sha256=d8f59c0eb7cf6cd6da625c86fe3e39d31a120eae8bdb4284ad9b3bea17a58113 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/83/f7/66fb976fe99d0662293e168760410f5bf8fce14f11931eda7a75ea837e4f/Pillow-2.1.0-py3.3-win32.egg#sha256=aae27cbdf8548f41d75adbbd1cea4460bc94a175ce0b6939ae33a4b9e7124698 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/c9/c5/e88eb176e44272176bb4ecc8c8d46f60f00a497309930a147c68432c67e4/Pillow-2.1.0.win-amd64-py2.6.exe#sha256=a01196252f2bda07349d7b1fed5e28cf48489e0ad9dc73eb99c5517ce0a8ac42 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/e6/f0/7e6d01f026274363aaefb6b7e924f4b34b4a825a4bd8eaebfbd7d401af91/Pillow-2.1.0.win-amd64-py2.7.exe#sha256=7a9f23b5cb4d4c26f550dd584f6632cf8917b1b740b5508b0f37283d5cd04430 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/73/d3/8a126a4952ecedae65410d1233875910bb6b0678bff90c392804ebca3752/Pillow-2.1.0.win-amd64-py3.2.exe#sha256=4bf3b4f436ef645eb3d38fba181c848ed0beadac517e1e8f37dd6e00dc869acb (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/81/01/fcda325e63577c6ac92cf27496dd79f82c3f088d594f8611116fd3c4a207/Pillow-2.1.0.win-amd64-py3.3.exe#sha256=787a9a808a5e006bd522e362d01bf0bf9cdd9c02226f7de6153c642c1d9886be (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/5c/1e/ad009135828ff16dc30b00e34ce2bf75f60aab7fa8119e9a10f5ea223cf1/Pillow-2.1.0.win32-py2.6.exe#sha256=6604aed88ac82a56ab9b4933d2ebe2ee1b191c702c0538e77c0eadf133e4f2e2 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/7f/63/6b92da7f64c0fb93c1f90e08cbfac4ad67e063a941c996607b68af730a8a/Pillow-2.1.0.win32-py2.7.exe#sha256=c1499829ac2692deb9945ad45e8f7a06d399c0229cc3021603338eb8534e5af4 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/b1/4c/6a81d7adf185913e44b042fc58e304e1c60fe672c0ddc52296957a592be6/Pillow-2.1.0.win32-py3.2.exe#sha256=0aa16b1b824a835bc24382e0c03573e721cbcfe4fe94ac89e4d480bea55ba2fa (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/a2/c8/f46f4759e865330dd36010a49c47e9b57efc1344c293b33e2d2c4e9d659c/Pillow-2.1.0.win32-py3.3.exe#sha256=64c3104786ffb71e29058b5ee623d378892c10421e29272cbac38a37dc9f8cff (from https://pypi.org/simple/pillow/)
#   Found link https://files.pythonhosted.org/packages/3a/e5/818487cf35069d1da6d78d87cada08ddedb3deb665094b95a49af16ba917/Pillow-2.1.0.zip#sha256=c733088b9a6f856386d3fcff8c54b3c1bc623a69f7481348fe36320513d98076 (from https://pypi.org/simple/pillow/), version: 2.1.0
#   Found link https://files.pythonhosted.org/packages/d6/bd/881059152eb70ab98e2fa49d9e479059ad58965610edf038f07e8f5990bc/Pillow-2.2.0.zip#sha256=a66e71fc18247f0cd213ea829ac55901c3ad4c49c183ec8c98cc8ffaf0196644 (from https://pypi.org/simple/pillow/), version: 2.2.0
#   Skipping link: none of the wheel's tags (cp26-none-win32) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/89/57/0f835b60730b642f5205b459df332c27200d83c14c8b374300f3861406c6/Pillow-2.2.1-cp26-none-win32.whl#sha256=c81e4a676ca686ff1f04a6fefde5d9c753dfccce6fc8794b390a779b1039caae (from https://pypi.org/simple/pillow/)
#   Skipping link: none of the wheel's tags (cp26-none-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/8b/2a/f7049192a48846ee3c2ed56dcf7af901e6e55e59e60c5f11f71d488fcaae/Pillow-2.2.1-cp26-none-win_amd64.whl#sha256=68c02e7f6c03a7cd203ff26067ad44f070ff69849bc075c89fbc72f36cf84a4d (from https://pypi.org/simple/pillow/)
#   Skipping link: none of the wheel's tags (cp27-none-win32) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/08/6c/01d62f879d97d863cffa77da40afa54bf6af4bf60c5bb1aec08ad6167506/Pillow-2.2.1-cp27-none-win32.whl#sha256=9e1d97d03d5248c7f80ebbb8e4a89764bb9c2ebadfc3ffd90d0b923b228f7963 (from https://pypi.org/simple/pillow/)
#   Skipping link: none of the wheel's tags (cp27-none-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/38/06/ba0e46b53f79226ebc9363bea725b89144c592959614176e57534aed0df6/Pillow-2.2.1-cp27-none-win_amd64.whl#sha256=df8bd5392b194d283ac5c45524b917c2209c4f5f1afa6897317ec038775c39bb (from https://pypi.org/simple/pillow/)
#   Skipping link: none of the wheel's tags (cp32-none-win32) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/48/1a/a1547da492446c73f5ef2780514a814441b152f51c03ca4ab04bf4576fce/Pillow-2.2.1-cp32-none-win32.whl#sha256=9adfd3e87beacd472afdadc840f9b0dc3a71cc62d127c900ae293aa0126c7f8c (from https://pypi.org/simple/pillow/)
#   Skipping link: none of the wheel's tags (cp32-none-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/87/35/d814c1abf3d25cf5f9a5deb426438bdd4aae3a8ed0d15d68b57c6c7c998f/Pillow-2.2.1-cp32-none-win_amd64.whl#sha256=1a45bd9bb5203c83ebd0378e9e30a5b12395cc2b2adcc459e713324660aefc3d (from https://pypi.org/simple/pillow/)
#   Skipping link: none of the wheel's tags (cp33-none-win32) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/71/1b/6a84fd3a954cf24a88f6bc1c267cbdccd7316987049e9abfbe475bdd6be6/Pillow-2.2.1-cp33-none-win32.whl#sha256=f4fd8ad3671aeb3a1ebdb8ac88cce84385c2b99daff190faf0373304436a32de (from https://pypi.org/simple/pillow/)
#   Skipping link: none of the wheel's tags (cp33-none-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/93/33/3d94ec8498ee6b149f263f0cf0c548f3b68ebf95d5a32c7597dc1d50a2c8/Pillow-2.2.1-cp33-none-win_amd64.whl#sha256=2cd0099e2baaafb9b30d94920aca470c6e51897930bacae29f3e7e0c9104b0b9 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/3e/ca/b29d23ba029582eff3079e99828efb99954f9c99e04edcae899bafa356e0/Pillow-2.2.1-py2.6-win-amd64.egg#sha256=e819147f65e930d5fcb7585540704a2a95d50b2898d51ed087d44aa2ec05cd92 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/b0/6e/0a856a7bda3ba8384a1d619a5982568ef803115efdbdadc8eb70488cbc29/Pillow-2.2.1-py2.6-win32.egg#sha256=26a98b72ed9532137137f8c00023ad086168737f9c48ec2643476c2aac852e6c (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/40/90/dc25368e12d31ec39b6cfb51fb1146fd0fdb41014a688ed74b28d9cabc4d/Pillow-2.2.1-py2.7-win-amd64.egg#sha256=aedcd1dd5cedde18be5af147e158c8bbea110c592035e77ce4f22a9636a47b76 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/27/5d/c3901cc5aaabaef594e17763dd20d0f8a0b52d8376d46639ef729f334a7e/Pillow-2.2.1-py2.7-win32.egg#sha256=31eb7bb9d249d815cad99a2593992e96cc6c8efec4d34145f203b17396df2366 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/37/ef/06cb88468f1189cfbc9f6b1b2370531d8ae499d0703ff7203e469b0bcae1/Pillow-2.2.1-py3.2-win-amd64.egg#sha256=146a40ede80fdbfa37cf13df5a3ec971c93ae971653be5c872623ce3433f91fc (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/5b/13/d61cec335f546f62f569cb0b254921250f0adcd367df6c567a8f5e81a94d/Pillow-2.2.1-py3.2-win32.egg#sha256=f68396dbff92341ce4a02bb675f6fb02cb02579ede40b6f7c4faa405ce640e2a (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/b4/b8/d84bfe7c4cca78ef4ae4a6dd411c776033ec02aac77ed440283a16e0abc9/Pillow-2.2.1-py3.3-win-amd64.egg#sha256=6d02cfe4a2151595bbee08cb7a7fda348e60d1a68ce8118ef152b7c42f20aea7 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/4d/fb/fb90a6642411aa7693989f1f1a020bf651feb289e39c33b558f6940f6eab/Pillow-2.2.1-py3.3-win32.egg#sha256=4b694f71674778bf02596bc47f7696f8dce0277b9350a30f8ed21784c9939ffd (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/e3/73/a42de329d29ad36f62a5f00f47e05f64db6bad37a31a82f2308a2012f753/Pillow-2.2.1.win-amd64-py2.6.exe#sha256=1c9a814cbafe293b50b9cf91ae3dadf298ce8ec21609bf53f1921f45a9e4f124 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/2e/3f/c8f54a26ac72fbff17c0e237bfb889e6cec550902ed59ec5d9313fee05b1/Pillow-2.2.1.win-amd64-py2.7.exe#sha256=9a81add9d2c48932989c54eb2d255669f8b904039b2098eead76acfcefc64541 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/01/db/313173bb7484464ffca1cd848105cc3dca650019b447adf0e91d76ee0ed9/Pillow-2.2.1.win-amd64-py3.2.exe#sha256=90cee5deca2ffe6bc9c1e23fe60e7702b4d62a05cefbe83e7ad0b2f40d2c4290 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/40/a9/841687707836a40809a112a53f8cf6a39c62a7a9867892aea9b1faa94a5f/Pillow-2.2.1.win-amd64-py3.3.exe#sha256=722b14433d76a735bc5ba93b05b2365c06c793f38fbb78aa8b3ff220179cdb54 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/a6/e0/aa8761b5604b11cdec1a5a04f674517a5adf0d2b76d12892eb8c088647a0/Pillow-2.2.1.win32-py2.6.exe#sha256=460547650cc475dc923ccde6598ebd908b10e1710ea37bb51c6ae24667362b1d (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/1d/56/656a2560f9d7a972b3a26ffc5363006b05fe97fede44036dbfc645750872/Pillow-2.2.1.win32-py2.7.exe#sha256=2fbff632eb79965fcd7e610ed539592fb19498c39c00c29bd869115373c3c3dc (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/46/2d/0fb3bd93dc2a85d13d2c9896a0193faa1cf1c903a356e15d2616d5221b43/Pillow-2.2.1.win32-py3.2.exe#sha256=3b10db3c676f3c9faa322ad375451b74c7dcd06cbf88e081d9044f2c2a77e81b (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/45/8e/b2334dcded8001d35bf5e4d67f6c23a0bedf1dd2f43b1d25c5598fc56831/Pillow-2.2.1.win32-py3.3.exe#sha256=659f68b8b45a7322707fa1851ac2c845f52024678f3306026df84fc9c98a4fa3 (from https://pypi.org/simple/pillow/)
#   Found link https://files.pythonhosted.org/packages/b4/6d/f313f1bff98f6d1e353918e0a4e8e17a22af86f0ad10c231228342edf74d/Pillow-2.2.1.zip#sha256=a8440145d6e08db16f2a03b134b057c4524809e18a06cc8fe0e5e885dc4d8969 (from https://pypi.org/simple/pillow/), version: 2.2.1
#   Skipping link: none of the wheel's tags (cp26-none-win32) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/23/62/e330361f8acd934de45e41d66406b790e36985f3bcab6c1b5a3d4a368b45/Pillow-2.2.2-cp26-none-win32.whl#sha256=7e821bae3b7017d76d7144827d8aaebedb7d007d9e4867f22cb6146c994fd35b (from https://pypi.org/simple/pillow/)
#   Skipping link: none of the wheel's tags (cp26-none-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/6f/e4/9ae80efa182aa17613e6c2862698ff9a78abce050eb764c4feef91ed4624/Pillow-2.2.2-cp26-none-win_amd64.whl#sha256=0d9cc6db5c5af11e3696ab4c85a69a6190588dd48bf1ef839020d4b0e6add1c6 (from https://pypi.org/simple/pillow/)
#   Skipping link: none of the wheel's tags (cp27-none-win32) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/f9/12/b172cce53fabc46d3301c163f38f0d3480ffb807f441d46afb5b778a42ae/Pillow-2.2.2-cp27-none-win32.whl#sha256=f334f2b04495d5527d29be7dc78e64d80b72be83d814eb5031447c487d92f53d (from https://pypi.org/simple/pillow/)
#   Skipping link: none of the wheel's tags (cp27-none-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/80/e3/9b74efbaa06a24fd582c8612662e45aeaed50ef91bd6e764796bd5db96aa/Pillow-2.2.2-cp27-none-win_amd64.whl#sha256=76e87df9189854224fb6282046a3fb0b91470f9b7f14ec510588e61217efd726 (from https://pypi.org/simple/pillow/)
#   Skipping link: none of the wheel's tags (cp32-none-win32) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/c8/3d/9f8c49ebb14a1ca65bd0d781fbbd15f0c285f6d9dede311c580265139097/Pillow-2.2.2-cp32-none-win32.whl#sha256=83783dd80c21d29b6d511a7dbddfd16ced16696e646661b14a553b685b0cb613 (from https://pypi.org/simple/pillow/)
#   Skipping link: none of the wheel's tags (cp32-none-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/40/87/3deec996e9e8d1b97ce38980a0cf104a94b97dc8ca063e61b22a7cf8ae29/Pillow-2.2.2-cp32-none-win_amd64.whl#sha256=aa9a8b642ec825279e75b1e569245beb5d695233ddb934c89aa7edf4e40b8f70 (from https://pypi.org/simple/pillow/)
#   Skipping link: none of the wheel's tags (cp33-none-win32) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/cc/af/cc097dbcc507ec7e2d55131949f62181081beae38729eefeda4590ebb154/Pillow-2.2.2-cp33-none-win32.whl#sha256=a033e22d6a6711761cfae09338b62c3e8d978a73ae6fc8641fcd8333d1bb8a63 (from https://pypi.org/simple/pillow/)
#   Skipping link: none of the wheel's tags (cp33-none-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/37/c7/c4781b139ae646b50fa6fdccac969b3539ed7e8f0f335b8fc57cd765281d/Pillow-2.2.2-cp33-none-win_amd64.whl#sha256=99872c4eabda8c996ee9f672086ab78429f26ffbd448ce85e60f777306eade89 (from https://pypi.org/simple/pillow/)
#   Skipping link: none of the wheel's tags (cp34-none-win32) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/a5/e5/3c1167d7d15f94ba1d5104964dc4f83bbe6e3fac9b29dcfb6a7cd20035fa/Pillow-2.2.2-cp34-none-win32.whl#sha256=b9e9a035207de26b220d3a704fe054295a863251802277b2ec903626db71fa75 (from https://pypi.org/simple/pillow/)
#   Skipping link: none of the wheel's tags (cp34-none-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/3a/18/0f403383a839a7451c5ad7501746425b65aaf568bae93584ce5a24b61eff/Pillow-2.2.2-cp34-none-win_amd64.whl#sha256=3e2783eeca780856c42ec467842addfba341ac939fb3c9caa5ee46b4d3b7ab8a (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/aa/f9/9f6d75b082c577bd54b972a11d0a449f277503a8dd99d0f5d3287ab1cefd/Pillow-2.2.2-py2.6-win-amd64.egg#sha256=be7111cf17698b64c133ef3c35c785ec775bfd6ee51ea803465919c1378eda8a (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/c4/15/d9f8229f9de477a1d1ab105d0b8c466312a9cfbf77820c842af303e87f34/Pillow-2.2.2-py2.6-win32.egg#sha256=b2b5abfc76c0d458f08b33557f6260d318e14480b4eddfaed9b5bec71e855aef (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/eb/2b/d05e6038ef085359bf062dd5c2dec812443a02cb785619d4be1a07c8218b/Pillow-2.2.2-py2.7-win-amd64.egg#sha256=cdc8298d3352cb6d04b2afff8a033f0102646b54b1b9f25cb2f3d03e60b9a690 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/72/8f/c198f20590a027de05a0cb3f11aff091bd093c5ae8b9571929150d826963/Pillow-2.2.2-py2.7-win32.egg#sha256=939002aecf1604123d7937b2905950828a3aea6117216b90f490b2423ce4bcc5 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/8c/37/89fb24208c1a915eed511e0a22353c617ddbdc6913300d0a1c335f89ca08/Pillow-2.2.2-py3.2-win-amd64.egg#sha256=e93cc5bbc12fccf1a7966971ad1d11e58b2d047274435c11fd0b5f6c13fe2ac0 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/c9/8f/3052e4b57e5cbee4be39c039420a9dadd87685696297ab8e8e11b357be51/Pillow-2.2.2-py3.2-win32.egg#sha256=42bec3a2ec1d21d18e78bbbd56b8ed0f38bf2579dd625034d020e7745267b6cb (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/46/4a/87beff521be960c46c1314713d4b8690c7e13cb388e86e08d22ff86abe76/Pillow-2.2.2-py3.3-win-amd64.egg#sha256=22cddc2e80f0c824793518c00eb86979b884d922a6d00ade2077b1a464120750 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/32/32/91e368224d7e41140b922982d33a994c875a9c7a6fd263e6205415da619c/Pillow-2.2.2-py3.3-win32.egg#sha256=3c56604c708813af3455804c6c4be2be7304d55d43971425b05a24f747db6980 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/3a/89/d284b1bba386a863eba0bbe3b6fcab17064171ede93044ce7f5c8d0737d1/Pillow-2.2.2-py3.4-win-amd64.egg#sha256=8e74841760e12debe6c41079da7cf9574ce8774487683e259a94e017a26febff (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/65/99/d2fee1059fb1c0f8090d5e6de5951f57e2b50951e2efdb81b3a814f0a4e5/Pillow-2.2.2-py3.4-win32.egg#sha256=3f0879dac036d0eb035a40f9daca02d488ddaa96c79092655b7aca3230b2b616 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/01/93/7a562d5b538ff69e0848ba74e1449a816bf1e3ed5fb3c365030a12e3a368/Pillow-2.2.2.win-amd64-py2.6.exe#sha256=a68cae5c9ca3394580d8f3ecf746a52d04622aa0a09d366c75900d6ac2bc05ca (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/dd/9f/b6b1adb51a3fa7e0b29f4b9c6c9de117dec00add5cffbd6d12ee9d379f03/Pillow-2.2.2.win-amd64-py2.7.exe#sha256=74304a67e2419afb3a433974ad575e0a1abfa3ac808ff632da2915dd5e07b35e (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/8f/c4/e7cd4ca1e3bdf57e38c4725fa2bd2cc2c689501a59f734d90631af80c965/Pillow-2.2.2.win-amd64-py3.2.exe#sha256=75f03fad60f831ac8c0b0e60da967d3ab4d3b02531f8e2c8a7f5e99e8df276d8 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/ae/47/ac0fa9845d4b7b1c3201b0fb35284168420e61d6cbc2e0e42f894ccdc7cb/Pillow-2.2.2.win-amd64-py3.3.exe#sha256=6e599e0ceec4a4cdb85105a082c8b6818ae64ccf9ffdb17713f410bb0742ee77 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/88/85/cfe46c369aa4bd6fb8ae01b650db0ce0cea4c4e6202390beecba8840ce2e/Pillow-2.2.2.win-amd64-py3.4.exe#sha256=8e010ec90d0a305dd450758cdbd4509cffc5d1a32b183bd5859ad8a5661f29a7 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/78/cb/bdb6eca3b8b6c6576daae1ec3db141f18aeca1a17966904bdcd5da1fc534/Pillow-2.2.2.win32-py2.6.exe#sha256=f66a9b32781c0b4327d0a4fe70e2361ae109186cdb9e63c18429f5d3befdbdaf (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/b8/8d/7914cb13ec9f9ab5810ffcc5f0706f52eaba2902f944d117b6f35b407baa/Pillow-2.2.2.win32-py2.7.exe#sha256=949ec2c891d2b38527393a20c60afc30c096b69f9b8cbc269ff61c428365f138 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/33/08/9c2ef91a0e754ecaeb058ab59f974731143d0dc6c2b2a9a5c374f788b46f/Pillow-2.2.2.win32-py3.2.exe#sha256=888946c5a3f319e92a1d8f2a51a7ca40cab709fd3fc6e17e57c052942ddb8c43 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/93/24/eb59c32fee51dbba8cbc9f432637c4f9f66fd6005b077eeb14ff997c743e/Pillow-2.2.2.win32-py3.3.exe#sha256=d8167eb1bdd283db53fe97dd1a45d480aa5f39a03d4c93def19af5d11fe8a5f9 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/f7/15/5a3a7fbb5e0fc7a3346c3d354008ed2dc23a08e12b63535669af6f7b40c8/Pillow-2.2.2.win32-py3.4.exe#sha256=4a92ef07d49fe718e0b144dc70c8d089b107f17a2eaf26cb1221e73834a14493 (from https://pypi.org/simple/pillow/)
#   Found link https://files.pythonhosted.org/packages/90/6e/bd5decf0621e47c635448bf45760c06c473ca36fe6152f06dfb6ffa0518e/Pillow-2.2.2.zip#sha256=db49a634e981916c64954ec8da3142b88f1769608550b870b9184986db82a421 (from https://pypi.org/simple/pillow/), version: 2.2.2
#   Skipping link: none of the wheel's tags (cp26-none-win32) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/d2/31/d66a9ddf6838e22bc68f5e44879fde7f5ffbdcfb9a597e488a223ea19c37/Pillow-2.3.0-cp26-none-win32.whl#sha256=c99dc21acd143451244a69f773416c91856a26d9ee02e45c48da445858ea829c (from https://pypi.org/simple/pillow/)
#   Skipping link: none of the wheel's tags (cp26-none-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/62/02/1125763c0a63b4c74aab40cbcbdd895ab316eac270eaeb0ff473abba0ee6/Pillow-2.3.0-cp26-none-win_amd64.whl#sha256=b6498f9b8c0735765d83f4da21ab0b538e509c82d8266ef7ad53ac06fa33dc2f (from https://pypi.org/simple/pillow/)
#   Skipping link: none of the wheel's tags (cp27-none-win32) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/e2/20/f847c81607349a0e4451dc9f854c3b7f09cb4dce70edd366985bedc13208/Pillow-2.3.0-cp27-none-win32.whl#sha256=312e135137020ee8f265e3535b66cbf65a8d20594674a5f345ef1b5b2a26a982 (from https://pypi.org/simple/pillow/)
#   Skipping link: none of the wheel's tags (cp27-none-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/c6/11/b7421e3174d0f453d88e5ec7bc209c8be559650bed22d22bb687d5c5797c/Pillow-2.3.0-cp27-none-win_amd64.whl#sha256=0abe1e26449a6ed35231c1dea50e8b267a1d29b2ea390e9d366979dd804c62f9 (from https://pypi.org/simple/pillow/)
#   Skipping link: none of the wheel's tags (cp32-none-win32) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/54/d7/c57d3692e197a9bd25323a7264518697424b79760aca3d15b4ee1ebdbccb/Pillow-2.3.0-cp32-none-win32.whl#sha256=e04a17f11c7ea47de2d073874cb164cb50fb76db2516cde17fa4e9042aba7d6e (from https://pypi.org/simple/pillow/)
#   Skipping link: none of the wheel's tags (cp32-none-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/41/02/e87320f7929c1c6b8bc7de6a3f84097612fbb3fc7af64033a9a0daa22494/Pillow-2.3.0-cp32-none-win_amd64.whl#sha256=dd8b53cf5b434613f2dfe66efeb76a3ad73e5b6f4df5aa4c3ff7c6f7d7e3833c (from https://pypi.org/simple/pillow/)
#   Skipping link: none of the wheel's tags (cp33-none-win32) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/02/20/193a516b3915936edb2bd5126c1d960cad6c5dc73a93b27fc8632a118ef8/Pillow-2.3.0-cp33-none-win32.whl#sha256=a80c5afdf48e761c6bfd3eab6dce9501338b834f83d3cfd9bae2cd1fe93c70f8 (from https://pypi.org/simple/pillow/)
#   Skipping link: none of the wheel's tags (cp33-none-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/62/c2/e2f648df53a7603f12433d2dab80d2c8d923c10804456e4a4e876f9ea189/Pillow-2.3.0-cp33-none-win_amd64.whl#sha256=997052d4a6b56ea4f3dad07a55342e869a993101d6f65d5c600836120d0c3bf8 (from https://pypi.org/simple/pillow/)
#   Skipping link: none of the wheel's tags (cp34-none-win32) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/c8/d4/1255cde21cbc3604d98aaa047aaed6fa740ffb40ad81eec0bd21606a8373/Pillow-2.3.0-cp34-none-win32.whl#sha256=c709ed33fefa46ba37e6350f2fb17230256744b3b7222668ec1da0e8f4d8c705 (from https://pypi.org/simple/pillow/)
#   Skipping link: none of the wheel's tags (cp34-none-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/39/b1/5e4e18772dff6490bab351dd9e365b4059b6d2ecb9f8938085d7618c242a/Pillow-2.3.0-cp34-none-win_amd64.whl#sha256=4ede19c5302b2d531b6c2b4e66d641530f2db964a7103f0e886d509f4eae1d1a (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/9f/76/1c1a0f9ed4a788e8dcbe39e8f977d6f31fe997114934800e725d783de33e/Pillow-2.3.0-py2.6-win-amd64.egg#sha256=4ead7408aca64be1b82ddbf4f66e141be6cc30c813a8f372fff30e69f898093d (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/86/a3/e8f4f4bbae2625e164f16cd6c3b42991969e2441dd6624ae576346419317/Pillow-2.3.0-py2.6-win32.egg#sha256=5bb2f00311cb6718af5c311a0c4b5424d2145c9ba2a676fafe4de2d969f1ecde (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/8e/c6/1892c24c965720c20a61bc506cc2ffca903e2d52e28ed9be55f8e6246363/Pillow-2.3.0-py2.7-win-amd64.egg#sha256=de49b9119f06ba65a177b18062f8fdb23b71c662d7c97418ad3b200a083a8cdb (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/7b/ba/69eaf5168336a8ca48277d4236e09e72b240d8ca01cd322c142ff5b20386/Pillow-2.3.0-py2.7-win32.egg#sha256=380522ef0454b8a312acc864e01b8e070df17ba0d44438824767f472282d9da1 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/40/66/061fe3d35e83607f9ea81ccd504e26ffb41ad2583721c56d9abd39a437fa/Pillow-2.3.0-py3.2-win-amd64.egg#sha256=6a44dcd7dff17cd44b8a9275d6ce6fff6fd030c00f48ee4b054f5f9a07b9d532 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/a7/f0/991c014d33d87370539ec42df0fe00e9b9f38aebed40f72a67d3158ef79f/Pillow-2.3.0-py3.2-win32.egg#sha256=c795f2e636c81a22145feff526dca920b903d0d1bf4d7e38800eb5d6ded0b4ce (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/f7/17/1b00268488645bbfd36affeea6bb84c2b3a66e11007b68249c991c4dcaec/Pillow-2.3.0-py3.3-win-amd64.egg#sha256=dd1412f24de8f1d731927a99375cfdef6b1a09d6a9be11a672341c190fb0a8cf (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/f5/a3/f73dc296b5a4490f4abeeeac6736438acc8bae51a9ba6516226139f759e5/Pillow-2.3.0-py3.3-win32.egg#sha256=942bddd5f22577bf9a43d737daec835fb38b32f79affc5e92c88c7187adce20c (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/58/79/9a3bf86e28cbf15ecea8b4514066bf20e8bcddab1dc64cdff70365d3a128/Pillow-2.3.0-py3.4-win-amd64.egg#sha256=a6ecb3f31c36231df44c86be839a0b38f7e3f6fbf7682b2de584fb00979be376 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .egg: https://files.pythonhosted.org/packages/03/bc/bf142615f0577ab7018ef507f1f9b319ef5053eba6054f5a703a98a38839/Pillow-2.3.0-py3.4-win32.egg#sha256=e13a4cc819bc603b1e51416cdddfb931c138cd6d12ce419f6caac6d1707c12dc (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/ad/c1/7c490d6951d64ce937c0afbf38dd7b88dd2293e0c5c0581d6a156aa3139c/Pillow-2.3.0.win-amd64-py2.6.exe#sha256=c1f5b27346244fd42f1b5f00c3cbee309f00185faadd09b957c71877e88a5389 (from https://pypi.org/simple/pillow/)
#   Skipping link: unsupported archive format: .exe: https://files.pythonhosted.org/packages/78/52/b4c8abb64c68d131dfb723670cb812b62ea8788e66dc0d1cb5542646af67/Pillow-2.3.0.win-amd64-py2.7.exe#sha256=292589882e6f13458504cf26a1952559422bdd9e5d80d25104915d444d93c83d (from https://pypi.org/simple/pillow/)
# ...
#   Skipping link: none of the wheel's tags (cp37-cp37m-manylinux2014_i686, cp37-cp37m-manylinux_2_17_i686) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/5c/24/96fd7ca59e5be5409659f57f73d85d70e8548e97b187e381cd14cf6f83f2/Pillow-8.4.0-cp37-cp37m-manylinux_2_17_i686.manylinux2014_i686.whl#sha256=1394a6ad5abc838c5cd8a92c5a07535648cdf6d09e8e2d6df916dfa9ea86ead8 (from https://pypi.org/simple/pillow/) (requires-python:>=3.6)
#   Found link https://files.pythonhosted.org/packages/a7/f3/c81e9c41c6ee4c99ad7436b7a1509f5bce5de4ccf4b83138cf88760d96ff/Pillow-8.4.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=792e5c12376594bfcb986ebf3855aa4b7c225754e9a9521298e460e92fb4a488 (from https://pypi.org/simple/pillow/) (requires-python:>=3.6), version: 8.4.0
#   Skipping link: none of the wheel's tags (cp37-cp37m-win32) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/76/76/bbb73ff9f97517c70fee1a3c4dc08e41da5eabef8f777119d6cd854bf7e5/Pillow-8.4.0-cp37-cp37m-win32.whl#sha256=d99ec152570e4196772e7a8e4ba5320d2d27bf22fdf11743dd882936ed64305b (from https://pypi.org/simple/pillow/) (requires-python:>=3.6)
#   Skipping link: none of the wheel's tags (cp37-cp37m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/3e/59/4d519b49a5dfae6be2f445ac59802db54b4356cb20a4c3d1599c03d82f59/Pillow-8.4.0-cp37-cp37m-win_amd64.whl#sha256=7b7017b61bbcdd7f6363aeceb881e23c46583739cb69a3ab39cb384f6ec82e5b (from https://pypi.org/simple/pillow/) (requires-python:>=3.6)
#   Skipping link: none of the wheel's tags (cp38-cp38-macosx_10_10_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/e7/05/6765368c2831c97ca3e07f21856a1332d7edd382876fb5d9248d2cabddf9/Pillow-8.4.0-cp38-cp38-macosx_10_10_x86_64.whl#sha256=d89363f02658e253dbd171f7c3716a5d340a24ee82d38aab9183f7fdf0cdca49 (from https://pypi.org/simple/pillow/) (requires-python:>=3.6)
#   Skipping link: none of the wheel's tags (cp38-cp38-macosx_11_0_arm64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/af/62/fc6e2c7ce2357d7c81866599ff5eae3cbae910880030d27233e2a9e2c4fb/Pillow-8.4.0-cp38-cp38-macosx_11_0_arm64.whl#sha256=0a0956fdc5defc34462bb1c765ee88d933239f9a94bc37d132004775241a7585 (from https://pypi.org/simple/pillow/) (requires-python:>=3.6)
#   Skipping link: none of the wheel's tags (cp38-cp38-manylinux2014_aarch64, cp38-cp38-manylinux_2_17_aarch64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/cf/87/a3eaccbaa926197ff1a2c5e9fc3bed65fcbdd9b7135b01734544020241a1/Pillow-8.4.0-cp38-cp38-manylinux_2_17_aarch64.manylinux2014_aarch64.whl#sha256=5b7bb9de00197fb4261825c15551adf7605cf14a80badf1761d61e59da347779 (from https://pypi.org/simple/pillow/) (requires-python:>=3.6)
#   Skipping link: none of the wheel's tags (cp38-cp38-manylinux2014_i686, cp38-cp38-manylinux_2_17_i686) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/90/4f/c9a31755eb9ca9927d87c0d367caf47edf46384b7f13916fec405a119509/Pillow-8.4.0-cp38-cp38-manylinux_2_17_i686.manylinux2014_i686.whl#sha256=72b9e656e340447f827885b8d7a15fc8c4e68d410dc2297ef6787eec0f0ea409 (from https://pypi.org/simple/pillow/) (requires-python:>=3.6)
#   Skipping link: none of the wheel's tags (cp38-cp38-manylinux2014_x86_64, cp38-cp38-manylinux_2_17_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/fe/f9/cd8b11ec15e27581c5e7affdf04d618d44fa9524dbeb429e5e728df6dc4c/Pillow-8.4.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=a5a4532a12314149d8b4e4ad8ff09dde7427731fcfa5917ff16d0291f13609df (from https://pypi.org/simple/pillow/) (requires-python:>=3.6)
#   Skipping link: none of the wheel's tags (cp38-cp38-win32) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/eb/3b/7396c88c3506330e0b50b6411d8084aedcdd1e9da3fe5e94fd8b3356e4ec/Pillow-8.4.0-cp38-cp38-win32.whl#sha256=82aafa8d5eb68c8463b6e9baeb4f19043bb31fefc03eb7b216b51e6a9981ae09 (from https://pypi.org/simple/pillow/) (requires-python:>=3.6)
#   Skipping link: none of the wheel's tags (cp38-cp38-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/ff/fb/506890622e1dcddaa3b215a6cef70d72c4e248feed0045eb52904d1ef80b/Pillow-8.4.0-cp38-cp38-win_amd64.whl#sha256=066f3999cb3b070a95c3652712cffa1a748cd02d60ad7b4e485c3748a04d9d76 (from https://pypi.org/simple/pillow/) (requires-python:>=3.6)
#   Skipping link: none of the wheel's tags (cp39-cp39-macosx_10_10_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/32/25/32889d2b7c577b5a454dd12194b2ecb9d87d4b49c15c278dc99bc8ff5d2e/Pillow-8.4.0-cp39-cp39-macosx_10_10_x86_64.whl#sha256=5503c86916d27c2e101b7f71c2ae2cddba01a2cf55b8395b0255fd33fa4d1f1a (from https://pypi.org/simple/pillow/) (requires-python:>=3.6)
#   Skipping link: none of the wheel's tags (cp39-cp39-macosx_11_0_arm64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/7d/88/a59b397f030e131accd4ca5a2ad7f1ac62347e6f4aadbe3dabd329aaded9/Pillow-8.4.0-cp39-cp39-macosx_11_0_arm64.whl#sha256=4acc0985ddf39d1bc969a9220b51d94ed51695d455c228d8ac29fcdb25810e6e (from https://pypi.org/simple/pillow/) (requires-python:>=3.6)
#   Skipping link: none of the wheel's tags (cp39-cp39-manylinux2014_aarch64, cp39-cp39-manylinux_2_17_aarch64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/24/06/3adcd81a7fed8423cef5b40436dfed6f849f876308b4dd5ecd118c95c9a2/Pillow-8.4.0-cp39-cp39-manylinux_2_17_aarch64.manylinux2014_aarch64.whl#sha256=0b052a619a8bfcf26bd8b3f48f45283f9e977890263e4571f2393ed8898d331b (from https://pypi.org/simple/pillow/) (requires-python:>=3.6)
#   Skipping link: none of the wheel's tags (cp39-cp39-manylinux2014_i686, cp39-cp39-manylinux_2_17_i686) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/63/ba/168d6c4a82e6de85802fbfc88bab6d6df57fb17b233d6ea7fb4362567349/Pillow-8.4.0-cp39-cp39-manylinux_2_17_i686.manylinux2014_i686.whl#sha256=493cb4e415f44cd601fcec11c99836f707bb714ab03f5ed46ac25713baf0ff20 (from https://pypi.org/simple/pillow/) (requires-python:>=3.6)
#   Skipping link: none of the wheel's tags (cp39-cp39-manylinux2014_x86_64, cp39-cp39-manylinux_2_17_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/2f/59/af1ac6f871dab6e7e5e7d3ad29a976ed529afe1ba08287e5337da8e30233/Pillow-8.4.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=b8831cb7332eda5dc89b21a7bce7ef6ad305548820595033a4b03cf3091235ed (from https://pypi.org/simple/pillow/) (requires-python:>=3.6)
#   Skipping link: none of the wheel's tags (cp39-cp39-win32) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/db/44/61fa720db441f8075d1a26597f391f46aad314951a5ebea3d7fd8542db1a/Pillow-8.4.0-cp39-cp39-win32.whl#sha256=5e9ac5f66616b87d4da618a20ab0a38324dbe88d8a39b55be8964eb520021e02 (from https://pypi.org/simple/pillow/) (requires-python:>=3.6)
#   Skipping link: none of the wheel's tags (cp39-cp39-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/20/ec/15a263f2c65d71cf62aa767f774c2381077e07beb1e9309a94461ec1cd29/Pillow-8.4.0-cp39-cp39-win_amd64.whl#sha256=3eb1ce5f65908556c2d8685a8f0a6e989d887ec4057326f6c22b24e8a172c66b (from https://pypi.org/simple/pillow/) (requires-python:>=3.6)
#   Skipping link: none of the wheel's tags (pp36-pypy36_pp73-macosx_10_10_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/94/f8/2185f20cd78e7c8479b3dce92cdc7a21be9733a6ed63333c8f14c03f2499/Pillow-8.4.0-pp36-pypy36_pp73-macosx_10_10_x86_64.whl#sha256=ddc4d832a0f0b4c52fff973a0d44b6c99839a9d016fe4e6a1cb8f3eea96479c2 (from https://pypi.org/simple/pillow/) (requires-python:>=3.6)
#   Skipping link: none of the wheel's tags (pp36-pypy36_pp73-manylinux2014_i686, pp36-pypy36_pp73-manylinux_2_17_i686) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/ca/d2/ee0ecb951a040fcadf8d8b3aae580a8a347ee7747e6c369fa68e93717011/Pillow-8.4.0-pp36-pypy36_pp73-manylinux_2_17_i686.manylinux2014_i686.whl#sha256=9a3e5ddc44c14042f0844b8cf7d2cd455f6cc80fd7f5eefbe657292cf601d9ad (from https://pypi.org/simple/pillow/) (requires-python:>=3.6)
#   Skipping link: none of the wheel's tags (pp36-pypy36_pp73-manylinux2014_x86_64, pp36-pypy36_pp73-manylinux_2_17_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/d4/46/d5772376f9b30ceef55c3faf322a292974467bc48b1efc1c89e7ec8359ca/Pillow-8.4.0-pp36-pypy36_pp73-manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=c70e94281588ef053ae8998039610dbd71bc509e4acbc77ab59d7d2937b10698 (from https://pypi.org/simple/pillow/) (requires-python:>=3.6)
#   Skipping link: none of the wheel's tags (pp37-pypy37_pp73-macosx_10_10_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/79/97/6c15cbf22dc4553ca3344703418d433a4f870b7081c5f41ce7ec48efc1fc/Pillow-8.4.0-pp37-pypy37_pp73-macosx_10_10_x86_64.whl#sha256=3862b7256046fcd950618ed22d1d60b842e3a40a48236a5498746f21189afbbc (from https://pypi.org/simple/pillow/) (requires-python:>=3.6)
#   Skipping link: none of the wheel's tags (pp37-pypy37_pp73-manylinux2014_i686, pp37-pypy37_pp73-manylinux_2_17_i686) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/d1/df/5e040e5d8bf9cda4385ff95e15e26aa44e8ee60bcb0607c4ab00ed323cfd/Pillow-8.4.0-pp37-pypy37_pp73-manylinux_2_17_i686.manylinux2014_i686.whl#sha256=a4901622493f88b1a29bd30ec1a2f683782e57c3c16a2dbc7f2595ba01f639df (from https://pypi.org/simple/pillow/) (requires-python:>=3.6)
#   Skipping link: none of the wheel's tags (pp37-pypy37_pp73-manylinux2014_x86_64, pp37-pypy37_pp73-manylinux_2_17_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/5f/32/ec0ec71300b40a3bc8f254247b4f08e3078615658456a9e1eda54e5c9718/Pillow-8.4.0-pp37-pypy37_pp73-manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=84c471a734240653a0ec91dec0996696eea227eafe72a33bd06c92697728046b (from https://pypi.org/simple/pillow/) (requires-python:>=3.6)
#   Skipping link: none of the wheel's tags (pp37-pypy37_pp73-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/5c/36/756c55b86f508f099fd4d71d394eba298222dd866ae821f288636570ab1d/Pillow-8.4.0-pp37-pypy37_pp73-win_amd64.whl#sha256=244cf3b97802c34c41905d22810846802a3329ddcb93ccc432870243211c79fc (from https://pypi.org/simple/pillow/) (requires-python:>=3.6)
#   Found link https://files.pythonhosted.org/packages/7d/2a/2fc11b54e2742db06297f7fa7f420a0e3069fdcf0e4b57dfec33f0b08622/Pillow-8.4.0.tar.gz#sha256=b8e2f83c56e141920c39464b852de3719dfbfb6e3c99a2d8da0edf4fb33176ed (from https://pypi.org/simple/pillow/) (requires-python:>=3.6), version: 8.4.0
# Skipping link: not a file: https://pypi.org/simple/pillow/
# Given no hashes to check 2 links for project 'pillow': discarding no candidates
# Collecting Pillow==5.3.0
#   Created temporary directory: /tmp/pip-unpack-v9f4anna
#   Looking up "https://files.pythonhosted.org/packages/62/8c/230204b8e968f6db00c765624f51cfd1ecb6aea57b25ba00b240ee3fb0bd/Pillow-5.3.0-cp37-cp37m-manylinux1_x86_64.whl" in the cache
#   No cache entry available
#   Starting new HTTPS connection (1): files.pythonhosted.org:443
#   https://files.pythonhosted.org:443 "GET /packages/62/8c/230204b8e968f6db00c765624f51cfd1ecb6aea57b25ba00b240ee3fb0bd/Pillow-5.3.0-cp37-cp37m-manylinux1_x86_64.whl HTTP/1.1" 200 1976365
#   Downloading Pillow-5.3.0-cp37-cp37m-manylinux1_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 5.2 MB/s eta 0:00:01  Ignoring unknown cache-control directive: immutable
#   Updating cache with response from "https://files.pythonhosted.org/packages/62/8c/230204b8e968f6db00c765624f51cfd1ecb6aea57b25ba00b240ee3fb0bd/Pillow-5.3.0-cp37-cp37m-manylinux1_x86_64.whl"
#   Caching due to etag
#      |████████████████████████████████| 2.0 MB 5.2 MB/s
#   Added Pillow==5.3.0 from https://files.pythonhosted.org/packages/62/8c/230204b8e968f6db00c765624f51cfd1ecb6aea57b25ba00b240ee3fb0bd/Pillow-5.3.0-cp37-cp37m-manylinux1_x86_64.whl#sha256=aade5e66795c94e4a2b2624affeea8979648d1b0ae3fcee17e74e2c647fc4a8a to build tracker '/tmp/pip-req-tracker-au2t4vd7'
#   Removed Pillow==5.3.0 from https://files.pythonhosted.org/packages/62/8c/230204b8e968f6db00c765624f51cfd1ecb6aea57b25ba00b240ee3fb0bd/Pillow-5.3.0-cp37-cp37m-manylinux1_x86_64.whl#sha256=aade5e66795c94e4a2b2624affeea8979648d1b0ae3fcee17e74e2c647fc4a8a from build tracker '/tmp/pip-req-tracker-au2t4vd7'
# Created temporary directory: /tmp/pip-unpack-6mhau22z
# Installing collected packages: Pillow
#   Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/lib/python3.7/dist-packages
#   sysconfig: /usr/lib/python3.7/site-packages
#   Value for scheme.purelib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/lib/python3.7/dist-packages
#   sysconfig: /usr/lib/python3.7/site-packages
#   Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/include/python3.7/Pillow
#   sysconfig: /usr/include/python3.7m/Pillow
#   Value for scheme.scripts does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/bin
#   sysconfig: /usr/bin
#   Value for scheme.data does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local
#   sysconfig: /usr
#   Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = None
#
# Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/lib/python3.7/dist-packages
# sysconfig: /usr/lib/python3.7/site-packages
# Value for scheme.purelib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/lib/python3.7/dist-packages
# sysconfig: /usr/lib/python3.7/site-packages
# Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/include/python3.7/UNKNOWN
# sysconfig: /usr/include/python3.7m/UNKNOWN
# Value for scheme.scripts does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/bin
# sysconfig: /usr/bin
# Value for scheme.data does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local
# sysconfig: /usr
# Additional context:
# user = False
# home = None
# root = None
# prefix = None
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bokeh 2.3.3 requires pillow>=7.1.0, but you have pillow 5.3.0 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed Pillow-5.3.0
# Removed build tracker: '/tmp/pip-req-tracker-au2t4vd7'

# %% [markdown]
# ---
#
#
# **ВНИМАНИЕ: На этом этапе обязательно перезагрузить рантайм (Runtime -> Restart Runtime). Иначе версия 5.3.0 не будет загружена в рантайм.**
#
# После перезапуска рантайма следует продолжить исполнять ячейки далее.
#
# ---

# %% [markdown]
# ## **Физтех-Школа Прикладной математики и информатики (ФПМИ) МФТИ**

# %% [markdown]
# # Путешествие по Спрингфилду.
#
#
# Сегодня вам предстоить помочь телекомпании FOX  в обработке их контента. Как вы знаете сериал Симсоны идет на телеэкранах более 25 лет и за это время скопилось очень много видео материала. Персоонажи менялись вместе с изменяющимися графическими технологиями   и Гомер 2018 не очень похож на Гомера 1989. Нашей задачей будет научиться классифицировать персонажей проживающих в Спрингфилде. Думаю, что нет смысла представлять каждого из них в отдельности.
#
#
#
#  ![alt text](https://vignette.wikia.nocookie.net/simpsons/images/5/5a/Spider_fat_piglet.png/revision/latest/scale-to-width-down/640?cb=20111118140828)

# %% [markdown]
# ### Установка зависимостей

# %%
# !pip install -U torch torchvision
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.10.0+cu111)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (0.11.1+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (3.10.0.2)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision) (5.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision) (1.19.5)

# %%
# ИСПРАВЛЕНИЕ: к сожалению этот код не работает у меня на коллабе
# плюс что-то намудрено с именами в репозитории pytorch
  
# установка подходящей версии torch

#from os.path import exists
#from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
#platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
#cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
#accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

#!pip install -q http://download.pytorch.org/whl/{accelerator}/torch-1.5.0%2B{platform}-linux_x86_64.whl torchvision
#import torch
# Out:
# ERROR: torch-1.5.0+cp36-cp36m-linux_x86_64.whl is not a valid wheel filename.

# %%
# ИСПРАВЛЕНИЕ:
# Вручную ищем и устанавливаем подходящуюю версию 
# https://download.pytorch.org/whl/torch_stable.html 
# !pip install -q 'https://download.pytorch.org/whl/cu101/torch-1.5.0%2Bcu101-cp36-cp36m-linux_x86_64.whl' torchvision
import torch
# Out:
# ERROR: torch-1.5.0+cu101-cp36-cp36m-linux_x86_64.whl is not a supported wheel on this platform.

# %%
# we will verify that GPU is enabled for this notebook
# following should print: CUDA is available!  Training on GPU ...
# 
# if it prints otherwise, then you need to enable GPU: 
# from Menu > Runtime > Change Runtime Type > Hardware Accelerator > GPU

import torch
import numpy as np

train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %%
# ВНИМАНИЕ: мы это уже сделали вначале ноутбука

# нам необходима версия pillow  5.3.0
# удалим старую версию и установим новую
#!pip uninstall -y Pillow
#!pip install Pillow==5.3.0
#import PIL
#print(PIL.PILLOW_VERSION)
# здесь должна быть версия 5.3.0. если это не так перехгрузите данный ноутбук:
# Menu > Runtime > Restart Runtime

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# ---
#
# **ВНИМАНИЕ: скачайте датасет с каггла и положите его в корень своего гугл диска!**
#
# ---

# %%
# ИСПРАВЛЕНИЕ
#!unzip -q /content/gdrive/My\ Drive/simpsons/data/dataset.zip -d train
#!unzip -q /content/gdrive/My\ Drive/simpsons/data/testset.zip -d test

# !unzip -q /content/gdrive/My\ Drive/journey-springfield.zip

# %%
# !ls train
# Out:
# simpsons_dataset

# %%
# !nvidia-smi
import torch
torch.cuda.is_available()
# Out:
# Sat Nov 27 12:13:16 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8    27W / 149W |      3MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# True

# %% [markdown]
# В нашем тесте будет 990 картнок, для которых вам будет необходимо предсказать класс.

# %%
import pickle
import numpy as np
from skimage import io

from tqdm import tqdm, tqdm_notebook
from PIL import Image
from pathlib import Path

from torchvision import transforms
from multiprocessing.pool import ThreadPool
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn

from matplotlib import colors, pyplot as plt
# %matplotlib inline

# в sklearn не все гладко, чтобы в colab удобно выводить картинки 
# мы будем игнорировать warnings
import warnings
warnings.filterwarnings(action='ignore', category=DeprecationWarning)
# Out:
# /usr/local/lib/python3.7/dist-packages/skimage/io/manage_plugins.py:23: UserWarning: Your installed pillow version is < 7.1.0. Several security issues (CVE-2020-11538, CVE-2020-10379, CVE-2020-10994, CVE-2020-10177) have been fixed in pillow 7.1.0 or higher. We recommend to upgrade this library.
#   from .collection import imread_collection_wrapper

# %%
# разные режимы датасета 
DATA_MODES = ['train', 'val', 'test']
# все изображения будут масштабированы к размеру 224x224 px
RESCALE_SIZE = 224
# работаем на видеокарте
DEVICE = torch.device("cuda")

# %% [markdown]
# https://jhui.github.io/2018/02/09/PyTorch-Data-loading-preprocess_torchvision/

# %% [markdown]
# Ниже мы исспользуем враппер над датасетом для удобной работы. Вам стоит понимать, что происходит с LabelEncoder и  с torch.Transformation.
#
# ToTensor конвертирует  PIL Image с параметрами в диапазоне [0, 255] (как все пиксели) в FloatTensor размера (C x H x W) [0,1] , затем производится масштабирование:
# $input = \frac{input - \mu}{\text{standard deviation}} \\$,      константы - средние и дисперсии по каналам на основе ImageNet
#
#
# Стоит также отметить, что мы переопределяем метод __getitem__ для удобства работы с данной структурой данных.
#  Также используется LabelEncoder для преобразования строковых меток классов в id и обратно. В описании датасета указано, что картинки разного размера, так как брались напрямую с видео, поэтому следуем привести их к одному размер (это делает метод  _prepare_sample)

# %%
class SimpsonsDataset(Dataset):
    """
    Датасет с картинками, который паралельно подгружает их из папок
    производит скалирование и превращение в торчевые тензоры
    """
    def __init__(self, files, mode):
        super().__init__()
        # список файлов для загрузки
        self.files = sorted(files)
        # режим работы
        self.mode = mode

        if self.mode not in DATA_MODES:
            print(f"{self.mode} is not correct; correct modes: {DATA_MODES}")
            raise NameError

        self.len_ = len(self.files)
     
        self.label_encoder = LabelEncoder()

        if self.mode != 'test':
            self.labels = [path.parent.name for path in self.files]
            self.label_encoder.fit(self.labels)

            with open('label_encoder.pkl', 'wb') as le_dump_file:
                  pickle.dump(self.label_encoder, le_dump_file)
                      
    def __len__(self):
        return self.len_
      
    def load_sample(self, file):
        image = Image.open(file)
        image.load()
        return image
  
    def __getitem__(self, index):
        # для преобразования изображений в тензоры PyTorch и нормализации входа
        if self.mode == 'train': 
            transform = transforms.Compose([
                transforms.Resize(size=(RESCALE_SIZE, RESCALE_SIZE)),
                transforms.RandomRotation(degrees=30),
                transforms.RandomHorizontalFlip(),
                transforms.ColorJitter(hue=.1, saturation=.1),
                transforms.ToTensor(),
                transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) 
            ])
        else:
            transform = transforms.Compose([
                transforms.Resize(size=(RESCALE_SIZE, RESCALE_SIZE)),
                transforms.ToTensor(),
                transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) 
            ])
        x = self.load_sample(self.files[index])
        x = transform(x)
        if self.mode == 'test':
            return x
        else:
            label = self.labels[index]
            label_id = self.label_encoder.transform([label])
            y = label_id.item()
            return x, y

# %%
def imshow(inp, title=None, plt_ax=plt, default=False):
    """Imshow для тензоров"""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt_ax.imshow(inp)
    if title is not None:
        plt_ax.set_title(title)
    plt_ax.grid(False)

# %%
TRAIN_DIR = Path('train/simpsons_dataset')
TEST_DIR = Path('testset/testset')

train_val_files = sorted(list(TRAIN_DIR.rglob('*.jpg')))
test_files = sorted(list(TEST_DIR.rglob('*.jpg')))

# %%
from sklearn.model_selection import train_test_split

train_val_labels = [path.parent.name for path in train_val_files]
train_files, val_files = train_test_split(train_val_files, test_size=0.25, \
                                          stratify=train_val_labels)

# %%
val_dataset = SimpsonsDataset(val_files, mode='val')

# %%
# uncomment if you have problem with pillow
# def register_extension(id, extension): Image.EXTENSION[extension.lower()] = id.upper()
# Image.register_extension = register_extension
# def register_extensions(id, extensions): 
#     for extension in extensions: register_extension(id, extension)
# Image.register_extensions = register_extensions

# %% [markdown]
# Давайте посмотрим на наших героев внутри датасета.

# %%
fig, ax = plt.subplots(nrows=3, ncols=3,figsize=(8, 8), \
                        sharey=True, sharex=True)
for fig_x in ax.flatten():
    random_characters = int(np.random.uniform(0,1000))
    im_val, label = val_dataset[random_characters]
    img_label = " ".join(map(lambda x: x.capitalize(),\
                val_dataset.label_encoder.inverse_transform([label])[0].split('_')))
    imshow(im_val.data.cpu(), \
          title=img_label,plt_ax=fig_x)

# %% [markdown]
# Можете добавить ваши любимые сцены и классифицировать их. (веселые результаты можно кидать в чат)

# %% [markdown]
# ### Построение нейросети
#
# Запустить данную сеть будет вашим мини-заданием на первую неделю, чтобы было проще участвовать в соревновании.
#
# Данная архитектура будет очень простой и нужна для того, чтобы установить базовое понимание и получить простенький сабмит на Kaggle
#
# <!-- Здесь вам предлагается дописать сверточную сеть глубины 4/5.  -->
#
# *Описание слоев*:
#
#
#
# 1. размерность входа: 3x224x224
# 2.размерности после слоя:  8x111x111
# 3. 16x54x54
# 4. 32x26x26
# 5. 64x12x12
# 6. выход: 96x5x5

# %%
# Очень простая сеть
class SimpleCnn(nn.Module):
  
    def __init__(self, n_classes):
        super().__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=8, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv3 = nn.Sequential(
            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv4 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv5 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=96, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        
        self.out = nn.Linear(96 * 5 * 5, n_classes)
  
  
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.conv5(x)

        x = x.view(x.size(0), -1)
        logits = self.out(x)
        return logits

# %%
def fit_epoch(model, train_loader, criterion, optimizer):
    running_loss = 0.0
    running_corrects = 0
    processed_data = 0
  
    for inputs, labels in train_loader:
        inputs = inputs.to(DEVICE)
        labels = labels.to(DEVICE)
        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        preds = torch.argmax(outputs, 1)
        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)
        processed_data += inputs.size(0)
              
    train_loss = running_loss / processed_data
    train_acc = running_corrects.cpu().numpy() / processed_data
    return train_loss, train_acc

# %%
def eval_epoch(model, val_loader, criterion):
    model.eval()
    running_loss = 0.0
    running_corrects = 0
    processed_size = 0

    for inputs, labels in val_loader:
        inputs = inputs.to(DEVICE)
        labels = labels.to(DEVICE)

        with torch.set_grad_enabled(False):
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            preds = torch.argmax(outputs, 1)

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)
        processed_size += inputs.size(0)
    val_loss = running_loss / processed_size
    val_acc = running_corrects.double() / processed_size
    return val_loss, val_acc

# %%
def train(train_files, val_files, model, epochs, batch_size):
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    history = []
    log_template = "\nEpoch {ep:03d} train_loss: {t_loss:0.4f} \
    val_loss {v_loss:0.4f} train_acc {t_acc:0.4f} val_acc {v_acc:0.4f}"

    with tqdm(desc="epoch", total=epochs) as pbar_outer:
        opt = torch.optim.Adam(model.parameters())
        criterion = nn.CrossEntropyLoss()

        for epoch in range(epochs):
            train_loss, train_acc = fit_epoch(model, train_loader, criterion, opt)
            print("loss", train_loss)
            
            val_loss, val_acc = eval_epoch(model, val_loader, criterion)
            history.append((train_loss, train_acc, val_loss, val_acc))
            
            pbar_outer.update(1)
            tqdm.write(log_template.format(ep=epoch+1, t_loss=train_loss,\
                                           v_loss=val_loss, t_acc=train_acc, v_acc=val_acc))
            
    return history

# %%
def predict(model, test_loader):
    with torch.no_grad():
        logits = []
    
        for inputs in test_loader:
            inputs = inputs.to(DEVICE)
            model.eval()
            outputs = model(inputs).cpu()
            logits.append(outputs)
            
    probs = nn.functional.softmax(torch.cat(logits), dim=-1).numpy()
    return probs

# %%
n_classes = len(np.unique(train_val_labels))
simple_cnn = SimpleCnn(n_classes).to(DEVICE)
print("we will classify :{}".format(n_classes))
print(simple_cnn)
# Out:
# we will classify :42
# SimpleCnn(
#   (conv1): Sequential(
#     (0): Conv2d(3, 8, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv5): Sequential(
#     (0): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (out): Linear(in_features=2400, out_features=42, bias=True)
# )

# %% [markdown]
# Запустим обучение сети.

# %%
if val_dataset is None:
    val_dataset = SimpsonsDataset(val_files, mode='val')
    
train_dataset = SimpsonsDataset(train_files, mode='train')

# %%
history = train(train_dataset, val_dataset, model=simple_cnn, epochs=2, batch_size=64)
# Out:
# epoch:   0%|          | 0/2 [00:00<?, ?it/s]
# loss 2.4318454990159766
# epoch:  50%|█████     | 1/2 [02:48<02:48, 168.17s/it]
# Epoch 001 train_loss: 2.4318     val_loss 1.8127 train_acc 0.3244 val_acc 0.5055
# loss 1.4243716833105329
# epoch: 100%|██████████| 2/2 [05:35<00:00, 167.97s/it]
# Epoch 002 train_loss: 1.4244     val_loss 1.2608 train_acc 0.6087 val_acc 0.6569

# %% [markdown]
# Построим кривые обучения

# %%
loss, acc, val_loss, val_acc = zip(*history)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-e2a6efbdf3bd> in <module>()
# ----> 1 loss, acc, val_loss, val_acc = zip(*history)
#
# NameError: name 'history' is not defined

# %%
plt.figure(figsize=(15, 9))
plt.plot(loss, label="train_loss")
plt.plot(val_loss, label="val_loss")
plt.legend(loc='best')
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-d9d440af569b> in <module>()
#       1 plt.figure(figsize=(15, 9))
# ----> 2 plt.plot(loss, label="train_loss")
#       3 plt.plot(val_loss, label="val_loss")
#       4 plt.legend(loc='best')
#       5 plt.xlabel("epochs")
#
# NameError: name 'loss' is not defined

# %%
plt.figure(figsize=(15, 9))
plt.plot(acc, label="train_acc")
plt.plot(val_acc, label="val_acc")
plt.legend(loc='best')
plt.xlabel("epochs")
plt.ylabel("acc")
plt.show()

# %% [markdown]
# ### Ну и что теперь со всем этим делать?

# %% [markdown]
# ![alt text](https://www.indiewire.com/wp-content/uploads/2014/08/the-simpsons.jpg)

# %% [markdown]
# Хорошо бы понять, как сделать сабмит.
# У нас есть сеть и методы eval у нее, которые позволяют перевести сеть в режим предсказания. Стоит понимать, что у нашей модели на последнем слое стоит softmax, которые позволяет получить вектор вероятностей  того, что объект относится к тому или иному классу. Давайте воспользуемся этим.

# %%
def predict_one_sample(model, inputs, device=DEVICE):
    """Предсказание, для одной картинки"""
    with torch.no_grad():
        inputs = inputs.to(device)
        model.eval()
        logit = model(inputs).cpu()
        probs = torch.nn.functional.softmax(logit, dim=-1).numpy()
    return probs

# %%
random_characters = int(np.random.uniform(0,1000))
ex_img, true_label = val_dataset[random_characters]
probs_im = predict_one_sample(simple_cnn, ex_img.unsqueeze(0))

# %%
idxs = list(map(int, np.random.uniform(0,1000, 20)))
imgs = [val_dataset[id][0].unsqueeze(0) for id in idxs]

probs_ims = predict(simple_cnn, imgs)

# %%
label_encoder = pickle.load(open("label_encoder.pkl", 'rb'))

# %%
y_pred = np.argmax(probs_ims,-1)

actual_labels = [val_dataset[id][1] for id in idxs]

preds_class = [label_encoder.classes_[i] for i in y_pred]

# %% [markdown]
# Обратите внимание, что метрика, которую необходимо оптимизировать в конкурсе --- f1-score. Вычислим целевую метрику на валидационной выборке.

# %%
from sklearn.metrics import f1_score

f1_score(actual_labels, preds_class)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-c87c3d6a5c8d> in <module>()
#       1 from sklearn.metrics import f1_score
#       2
# ----> 3 f1_score(actual_labels, preds_class)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1119         average=average,
#    1120         sample_weight=sample_weight,
# -> 1121         zero_division=zero_division,
#    1122     )
#    1123
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1258         warn_for=("f-score",),
#    1259         sample_weight=sample_weight,
# -> 1260         zero_division=zero_division,
#    1261     )
#    1262     return f
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1532     if beta < 0:
#    1533         raise ValueError("beta should be >=0 in the F-beta score")
# -> 1534     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1535
#    1536     # Calculate tp_sum, pred_sum, true_sum ###
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1339     # Convert to Python primitive type to avoid NumPy type / Python str
#    1340     # comparison. See https://github.com/numpy/numpy/issues/6784
# -> 1341     present_labels = unique_labels(y_true, y_pred).tolist()
#    1342     if average == "binary":
#    1343         if y_type == "binary":
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/multiclass.py in unique_labels(*ys)
#     106     # Check that we don't mix string type with number type
#     107     if len(set(isinstance(label, str) for label in ys_labels)) > 1:
# --> 108         raise ValueError("Mix of label input types (string and number)")
#     109
#     110     return np.array(sorted(ys_labels))
#
# ValueError: Mix of label input types (string and number)

# %% [markdown]
# Сделаем классную визуализацию,  чтобы посмотреть насколько сеть уверена в своих ответах. Можете исспользовать это, чтобы отлаживать правильность вывода.

# %%
import matplotlib.patches as patches
from matplotlib.font_manager import FontProperties

fig, ax = plt.subplots(nrows=3, ncols=3,figsize=(12, 12), \
                        sharey=True, sharex=True)
for fig_x in ax.flatten():
    random_characters = int(np.random.uniform(0,1000))
    im_val, label = val_dataset[random_characters]
    img_label = " ".join(map(lambda x: x.capitalize(),\
                val_dataset.label_encoder.inverse_transform([label])[0].split('_')))
    
    

    imshow(im_val.data.cpu(), \
          title=img_label,plt_ax=fig_x)
    
    actual_text = "Actual : {}".format(img_label)
            
    fig_x.add_patch(patches.Rectangle((0, 53),86,35,color='white'))
    font0 = FontProperties()
    font = font0.copy()
    font.set_family("fantasy")
    prob_pred = predict_one_sample(simple_cnn, im_val.unsqueeze(0))
    predicted_proba = np.max(prob_pred)*100
    y_pred = np.argmax(prob_pred)
    
    predicted_label = label_encoder.classes_[y_pred]
    predicted_label = predicted_label[:len(predicted_label)//2] + '\n' + predicted_label[len(predicted_label)//2:]
    predicted_text = "{} : {:.0f}%".format(predicted_label,predicted_proba)
            
    fig_x.text(1, 59, predicted_text , horizontalalignment='left', fontproperties=font,
                    verticalalignment='top',fontsize=8, color='black',fontweight='bold')

# %% [markdown]
# Попробуйте найти те классы, которые сеть не смогла расспознать. Изучите данную проблему, это понадобится в дальнейшем.

# %% [markdown]
# ### Submit на Kaggle

# %% [markdown]
# ![alt text](https://i.redd.it/nuaphfioz0211.jpg)

# %%
test_dataset = SimpsonsDataset(test_files, mode="test")
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=64)
probs = predict(simple_cnn, test_loader)

preds = label_encoder.inverse_transform(np.argmax(probs, axis=1))
test_filenames = [path.name for path in test_dataset.files]

# %%
# ДОБАВЛЕНО: создание сабмита
import pandas as pd
df = pd.DataFrame()
df['Id'] = test_filenames
df['Expected'] = preds
df.to_csv('gdrive/My Drive/simpsons_simple_cnn_baseline.csv', index=False)
# файл появится у вас на гугл диске

# %%
! ls
# Out:
# characters_illustration.png  label_encoder.pkl	sample_submission.csv  train
# gdrive			     sample_data	testset

# %%
# ЗДЕСЬ что-то не работает. Не понятно зачем читайют лейблы 
#import pandas as pd
#my_submit = pd.read_csv("gdrive/My Drive/simpsons/data/labels.csv")
#my_submit = pd.DataFrame({'Image_id': test_filenames, 'Expected': preds})
#my_submit.head()

# %%
# TODO : сделайте сабмит (это важно, если Вы не справляетесь, но дошли до этой ячейки, то сообщите в чат и Вам помогут)

# %% [markdown]
# ## Приключение?
#
# А теперь самое интересное, мы сделали простенькую сверточную сеть и смогли отправить сабмит, но получившийся скор нас явно не устраивает. Надо с этим что-то сделать.
#
# Несколько срочныйх улучшейни для нашей сети, которые наверняка пришли Вам в голову:
#
#
# *   Учим дольше и изменяем гиперпараметры сети
# *  learning rate, batch size, нормализация картинки и вот это всё
# *   Кто же так строит нейронные сети? А где пулинги и батч нормы? Надо добавлять
# *  Ну разве Адам наше все? [adamW](https://www.fast.ai/2018/07/02/adam-weight-decay/) для практика, [статейка для любителей](https://openreview.net/pdf?id=ryQu7f-RZ) (очень хороший анализ), [наши ](https://github.com/MichaelKonobeev/adashift/) эксперименты для заинтересованных.
#
# * Ну разве это deep learning? Вот ResNet и Inception, которые можно зафайнтьюнить под наши данные, вот это я понимаю (можно и обучить в колабе, а можно и [готовые](https://github.com/Cadene/pretrained-models.pytorch) скачать).
#
# * Данных не очень много, можно их аугументировать и  доучититься на новом датасете ( который уже будет состоять из, как  пример аугументации, перевернутых изображений)
#
# * Стоит подумать об ансамблях
#
#
# Надеюсь, что у Вас получится!
#
# ![alt text](https://pbs.twimg.com/profile_images/798904974986113024/adcQiVdV.jpg)

# %%
n_classes = len(np.unique(train_val_labels))

# %% [markdown]
# Добавим аугментацию в SimpsonsDataset

# %%
def create_dct_path_labels(train_files, train_labels):
    dct_simpsons = {}
    for label_i in np.unique(train_labels).tolist():
        dct_simpsons[label_i] = []

    for path_i, label_i in zip(train_files, train_labels):
        dct_simpsons[label_i].append(path_i)

    return dct_simpsons

# Создадим словарь в котором ключами будут персонажи Симпсонов, а значениями списки с путями к картинкам.
dct_path_train = create_dct_path_labels(train_files, train_dataset.labels)

# Дополним картинки классов у которых менее 100 картинок, до 100 картинок в классе
for person in dct_path_train:
    if len(dct_path_train[person]) < 100:
        dct_path_train[person] = dct_path_train[person] * (100 // len(dct_path_train[person]))
        dct_path_train[person].extend(dct_path_train[person][:100 - len(dct_path_train[person])])
# Проверим что получилось 
for person in dct_path_train:
    print(f"{person}\t{len(dct_path_train[person])}")
new_train_files = []

for person in dct_path_train:
    new_train_files.extend(dct_path_train[person])

val_dataset = SimpsonsDataset(val_files, mode='val')
new_train_dataset = SimpsonsDataset(new_train_files, mode='train')
# Out:
# abraham_grampa_simpson	685
# agnes_skinner	100
# apu_nahasapeemapetilon	467
# barney_gumble	100
# bart_simpson	1006
# carl_carlson	100
# charles_montgomery_burns	895
# chief_wiggum	739
# cletus_spuckler	100
# comic_book_guy	352
# disco_stu	100
# edna_krabappel	343
# fat_tony	100
# gil	100
# groundskeeper_willie	100
# homer_simpson	1684
# kent_brockman	373
# krusty_the_clown	904
# lenny_leonard	233
# lionel_hutz	100
# lisa_simpson	1015
# maggie_simpson	100
# marge_simpson	968
# martin_prince	100
# mayor_quimby	185
# milhouse_van_houten	809
# miss_hoover	100
# moe_szyslak	1089
# ned_flanders	1090
# nelson_muntz	269
# otto_mann	100
# patty_bouvier	100
# principal_skinner	895
# professor_john_frink	100
# rainier_wolfcastle	100
# ralph_wiggum	100
# selma_bouvier	100
# sideshow_bob	658
# sideshow_mel	100
# snake_jailbird	100
# troy_mcclure	100
# waylon_smithers	136

# %%
def fit_epoch(model, train_loader, criterion, optimizer):
    running_loss = 0.0
    running_corrects = 0
    processed_data = 0
  
    for inputs, labels in train_loader:
        inputs = inputs.to(DEVICE)
        labels = labels.to(DEVICE)
        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        preds = torch.argmax(outputs, 1)
        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)
        processed_data += inputs.size(0)
              
    train_loss = running_loss / processed_data
    train_acc = running_corrects.cpu().numpy() / processed_data
    return train_loss, train_acc

# %%
def eval_epoch(model, val_loader, criterion):
    model.eval()
    running_loss = 0.0
    running_corrects = 0
    processed_size = 0

    for inputs, labels in val_loader:
        inputs = inputs.to(DEVICE)
        labels = labels.to(DEVICE)

        with torch.set_grad_enabled(False):
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            preds = torch.argmax(outputs, 1)

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)
        processed_size += inputs.size(0)
    val_loss = running_loss / processed_size
    val_acc = running_corrects.double() / processed_size
    return val_loss, val_acc

# %%
def train(train_dataset, val_dataset, model, epochs, batch_size, shuffle=True, sampler=None):
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=shuffle, sampler=sampler, num_workers=4)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    history = []
    log_template = "\nEpoch {ep:03d} train_loss: {t_loss:0.4f} \
    val_loss {v_loss:0.4f} train_acc {t_acc:0.4f} val_acc {v_acc:0.4f}"

    with tqdm(desc="epoch", total=epochs) as pbar_outer:
        opt = torch.optim.AdamW(model.parameters(), lr=1e-4)
        scheduler = torch.optim.lr_scheduler.StepLR(opt, 3, 0.5)
        criterion = nn.CrossEntropyLoss()

        for epoch in range(epochs):
            train_loss, train_acc = fit_epoch(model, train_loader, criterion, opt)
            print("loss", train_loss)
            
            val_loss, val_acc = eval_epoch(model, val_loader, criterion)
            history.append((train_loss, train_acc, val_loss, val_acc))
            scheduler.step()
            pbar_outer.update(1)
            tqdm.write(log_template.format(ep=epoch+1, t_loss=train_loss,\
                                           v_loss=val_loss, t_acc=train_acc, v_acc=val_acc))
            
    return history

# %%
def predict(model, test_loader):
    with torch.no_grad():
        logits = []
    
        for inputs in test_loader:
            inputs = inputs.to(DEVICE)
            model.eval()
            outputs = model(inputs).cpu()
            logits.append(outputs)
            
    probs = nn.functional.softmax(torch.cat(logits), dim=-1).numpy()
    return probs

# %%
from torchvision import models

# %% [markdown]
# БУдем использовать Efficientnet_b2

# %%
model = models.efficientnet_b2(pretrained=True)

for param in model.parameters():
    param.requires_grad = True

model = model.cuda()
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b2_rwightman-bcdf34b7.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b2_rwightman-bcdf34b7.pth
#   0%|          | 0.00/35.2M [00:00<?, ?B/s]

# %%
history = train(new_train_dataset, val_dataset, model=model, epochs=10, batch_size=64)
import copy

# сохранить веса нашей нейросети model
model_pre_weights = copy.deepcopy(model.state_dict())
torch.save(model_pre_weights, "path_to\\model_10epochs_efficientnet_b2.pth")

test_dataset = SimpsonsDataset(test_files, mode="test")
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=64)
probs = predict(model, test_loader)
label_encoder = pickle.load(open("label_encoder.pkl", 'rb'))
preds = label_encoder.inverse_transform(np.argmax(probs, axis=1))
test_filenames = [path.name for path in test_dataset.files]

# ДОБАВЛЕНО: создание сабмита
import pandas as pd
df = pd.DataFrame()
df['Id'] = test_filenames
df['Expected'] = preds
df.to_csv('gdrive/My Drive/simpsons_efficientnet_baseline.csv', index=False)
# файл появится у вас на гугл диске
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# loss 2.1713235396769455
# epoch:  10%|█         | 1/10 [06:22<57:21, 382.43s/it]
# Epoch 001 train_loss: 2.1713     val_loss 0.4370 train_acc 0.6017 val_acc 0.8974
# loss 0.2931502564678745
# epoch:  20%|██        | 2/10 [12:40<50:37, 379.66s/it]
# Epoch 002 train_loss: 0.2932     val_loss 0.2243 train_acc 0.9243 val_acc 0.9473
# loss 0.1322280846904389
# epoch:  30%|███       | 3/10 [18:58<44:14, 379.25s/it]
# Epoch 003 train_loss: 0.1322     val_loss 0.2019 train_acc 0.9655 val_acc 0.9541
# loss 0.0611411867991253
# epoch:  40%|████      | 4/10 [25:17<37:52, 378.81s/it]
# Epoch 004 train_loss: 0.0611     val_loss 0.1744 train_acc 0.9834 val_acc 0.9631
# loss 0.03722038516396071
# epoch:  50%|█████     | 5/10 [31:34<31:32, 378.40s/it]
# Epoch 005 train_loss: 0.0372     val_loss 0.1847 train_acc 0.9899 val_acc 0.9635
# loss 0.028718013829571207
# epoch:  60%|██████    | 6/10 [37:52<25:12, 378.22s/it]
# Epoch 006 train_loss: 0.0287     val_loss 0.1878 train_acc 0.9921 val_acc 0.9656
# loss 0.01655178369083818
# epoch:  70%|███████   | 7/10 [44:11<18:55, 378.51s/it]
# Epoch 007 train_loss: 0.0166     val_loss 0.1824 train_acc 0.9951 val_acc 0.9668
# loss 0.011967051217791942
# epoch:  80%|████████  | 8/10 [50:30<12:36, 378.45s/it]
# Epoch 008 train_loss: 0.0120     val_loss 0.1753 train_acc 0.9966 val_acc 0.9685
# loss 0.009137832913321745
# epoch:  90%|█████████ | 9/10 [56:47<06:18, 378.26s/it]
# Epoch 009 train_loss: 0.0091     val_loss 0.1873 train_acc 0.9973 val_acc 0.9679
# loss 0.007163870913928419
# epoch: 100%|██████████| 10/10 [1:03:06<00:00, 378.60s/it]
# Epoch 010 train_loss: 0.0072     val_loss 0.1877 train_acc 0.9978 val_acc 0.9689

# %% [markdown]
# Видим что сеть довольно хорошо обучилась
